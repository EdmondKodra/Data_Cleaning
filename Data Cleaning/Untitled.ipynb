# %%
import pandas as pd

# Krijojmë një listë dictionaries me të dhënat që të dhatë
data = [
    {"CustomerID":1001,"First_Name":"Frodo","Last_Name":"Baggins","Phone_Number":"123-545-5421","Address":"123 Shire Lane, Shire","Paying Customer":"Yes","Do_Not_Contact":"No","Not_Useful_Column":True},
    {"CustomerID":1002,"First_Name":"Abed","Last_Name":"Nadir","Phone_Number":"123/643/9775","Address":"93 West Main Street","Paying Customer":"No","Do_Not_Contact":"Yes","Not_Useful_Column":False},
    {"CustomerID":1003,"First_Name":"Walter","Last_Name":"/White","Phone_Number":"7066950392","Address":"298 Drugs Driveway","Paying Customer":"N","Do_Not_Contact":None,"Not_Useful_Column":True},
    {"CustomerID":1004,"First_Name":"Dwight","Last_Name":"Schrute","Phone_Number":"123-543-2345","Address":"980 Paper Avenue, Pennsylvania, 18503","Paying Customer":"Yes","Do_Not_Contact":"Y","Not_Useful_Column":True},
    {"CustomerID":1005,"First_Name":"Jon","Last_Name":"Snow","Phone_Number":"876|678|3469","Address":"123 Dragons Road","Paying Customer":"Y","Do_Not_Contact":"No","Not_Useful_Column":True},
    {"CustomerID":1006,"First_Name":"Ron","Last_Name":"Swanson","Phone_Number":"304-762-2467","Address":"768 City Parkway","Paying Customer":"Yes","Do_Not_Contact":"Yes","Not_Useful_Column":True},
    {"CustomerID":1007,"First_Name":"Jeff","Last_Name":"Winger","Phone_Number":None,"Address":"1209 South Street","Paying Customer":"No","Do_Not_Contact":"No","Not_Useful_Column":False},
    {"CustomerID":1008,"First_Name":"Sherlock","Last_Name":"Holmes","Phone_Number":"876|678|3469","Address":"98 Clue Drive","Paying Customer":"N","Do_Not_Contact":"No","Not_Useful_Column":False},
    {"CustomerID":1009,"First_Name":"Gandalf","Last_Name":None,"Phone_Number":"N/a","Address":"123 Middle Earth","Paying Customer":"Yes","Do_Not_Contact":None,"Not_Useful_Column":False},
    {"CustomerID":1010,"First_Name":"Peter","Last_Name":"Parker","Phone_Number":"123-545-5421","Address":"25th Main Street, New York","Paying Customer":"Yes","Do_Not_Contact":"No","Not_Useful_Column":True},
    {"CustomerID":1011,"First_Name":"Samwise","Last_Name":"Gamgee","Phone_Number":None,"Address":"612 Shire Lane, Shire","Paying Customer":"Yes","Do_Not_Contact":"No","Not_Useful_Column":True},
    {"CustomerID":1012,"First_Name":"Harry","Last_Name":"...Potter","Phone_Number":"7066950392","Address":"2394 Hogwarts Avenue","Paying Customer":"Y","Do_Not_Contact":None,"Not_Useful_Column":True},
    {"CustomerID":1013,"First_Name":"Don","Last_Name":"Draper","Phone_Number":"123-543-2345","Address":"2039 Main Street","Paying Customer":"Yes","Do_Not_Contact":"N","Not_Useful_Column":False},
    {"CustomerID":1014,"First_Name":"Leslie","Last_Name":"Knope","Phone_Number":"876|678|3469","Address":"343 City Parkway","Paying Customer":"Yes","Do_Not_Contact":"No","Not_Useful_Column":False},
    {"CustomerID":1015,"First_Name":"Toby","Last_Name":"Flenderson_","Phone_Number":"304-762-2467","Address":"214 HR Avenue","Paying Customer":"N","Do_Not_Contact":"No","Not_Useful_Column":False},
    {"CustomerID":1016,"First_Name":"Ron","Last_Name":"Weasley","Phone_Number":"123-545-5421","Address":"2395 Hogwarts Avenue","Paying Customer":"No","Do_Not_Contact":"N","Not_Useful_Column":False},
    {"CustomerID":1017,"First_Name":"Michael","Last_Name":"Scott","Phone_Number":"123/643/9775","Address":"121 Paper Avenue, Pennsylvania","Paying Customer":"Yes","Do_Not_Contact":"No","Not_Useful_Column":False},
    {"CustomerID":1018,"First_Name":"Clark","Last_Name":"Kent","Phone_Number":"7066950392","Address":"3498 Super Lane","Paying Customer":"Y","Do_Not_Contact":None,"Not_Useful_Column":True},
    {"CustomerID":1019,"First_Name":"Creed","Last_Name":"Braton","Phone_Number":"N/a","Address":"N/a","Paying Customer":"N/a","Do_Not_Contact":"Yes","Not_Useful_Column":True},
    {"CustomerID":1020,"First_Name":"Anakin","Last_Name":"Skywalker","Phone_Number":"876|678|3469","Address":"910 Tatooine Road, Tatooine","Paying Customer":"Yes","Do_Not_Contact":"N","Not_Useful_Column":True},
    {"CustomerID":1020,"First_Name":"Anakin","Last_Name":"Skywalker","Phone_Number":"876|678|3469","Address":"910 Tatooine Road, Tatooine","Paying Customer":"Yes","Do_Not_Contact":"N","Not_Useful_Column":True}
]

# Krijo DataFrame
df = pd.DataFrame(data)

# Ruaj si CSV
df.to_csv('kosovo_customers.csv', index=False)

print("CSV file u krijua me sukses!")
# Out:
# CSV file u krijua me sukses!

# %%
df = df.drop_duplicates()
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger          None
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf         None           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee          None
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017    Michael        Scott  123/643/9775
# ...

# %%
df = df.drop(columns = "Not_Useful_Column")
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger          None
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf         None           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee          None
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017    Michael        Scott  123/643/9775
# ...

# %%
df["Last_Name"] = df["Last_Name"].str.strip("123._/")
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123/643/9775
# 2         1003     Walter       White    7066950392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876|678|3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger          None
# 7         1008   Sherlock      Holmes  876|678|3469
# 8         1009    Gandalf        None           N/a
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee          None
# 11        1012      Harry      Potter    7066950392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876|678|3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017    Michael       Scott  123/643/9775
# ...

# %%
df["Phone_Number"] = df["Phone_Number"].str.replace('nan--','')

df["Phone_Number"] = df["Phone_Number"].str.replace('Na--','')
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123/643/9775
# 2         1003     Walter       White    7066950392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876|678|3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger          None
# 7         1008   Sherlock      Holmes  876|678|3469
# 8         1009    Gandalf        None           N/a
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee          None
# 11        1012      Harry      Potter    7066950392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876|678|3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017    Michael       Scott  123/643/9775
# ...

# %%
df[["Street_Address", "State", "Zip_Code"]] = df["Address"].str.split(',',n=2, expand=True)
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123/643/9775
# 2         1003     Walter       White    7066950392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876|678|3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger          None
# 7         1008   Sherlock      Holmes  876|678|3469
# 8         1009    Gandalf        None           N/a
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee          None
# 11        1012      Harry      Potter    7066950392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876|678|3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017    Michael       Scott  123/643/9775
# ...

# %%
df["Do_Not_Contact"] = df["Do_Not_Contact"].str.replace('Yes','Y')

df["Do_Not_Contact"] = df["Do_Not_Contact"].str.replace('No','N')
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123/643/9775
# 2         1003     Walter       White    7066950392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876|678|3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger          None
# 7         1008   Sherlock      Holmes  876|678|3469
# 8         1009    Gandalf        None           N/a
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee          None
# 11        1012      Harry      Potter    7066950392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876|678|3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017    Michael       Scott  123/643/9775
# ...

# %%
df=df.fillna('')
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123/643/9775
# 2         1003     Walter       White    7066950392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876|678|3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876|678|3469
# 8         1009    Gandalf                       N/a
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter    7066950392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876|678|3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017    Michael       Scott  123/643/9775
# ...

# %%
for x in df.index:
    if df.loc[x, "Do_Not_Contact"] == 'Y':
        df.drop(x, inplace=True)

df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 2         1003     Walter       White    7066950392
# 4         1005        Jon        Snow  876|678|3469
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876|678|3469
# 8         1009    Gandalf                       N/a
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter    7066950392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876|678|3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017    Michael       Scott  123/643/9775
# 17        1018      Clark        Kent    7066950392
# 19        1020     Anakin   Skywalker  876|678|3469
#
#                            Address Paying Customer Do_Not_Contact  \
# ...

# %%
for x in df.index:
    if df.loc[x, "Phone_Number"] == '':
        df.drop(x, inplace=True)

df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 2         1003     Walter       White    7066950392
# 4         1005        Jon        Snow  876|678|3469
# 7         1008   Sherlock      Holmes  876|678|3469
# 8         1009    Gandalf                       N/a
# 9         1010      Peter      Parker  123-545-5421
# 11        1012      Harry      Potter    7066950392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876|678|3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017    Michael       Scott  123/643/9775
# 17        1018      Clark        Kent    7066950392
# 19        1020     Anakin   Skywalker  876|678|3469
#
#                            Address Paying Customer Do_Not_Contact  \
# 0            123 Shire Lane, Shire             Yes              N
# ...

# %%
df = df.reset_index(drop=True)
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1003     Walter       White    7066950392
# 2         1005        Jon        Snow  876|678|3469
# 3         1008   Sherlock      Holmes  876|678|3469
# 4         1009    Gandalf                       N/a
# 5         1010      Peter      Parker  123-545-5421
# 6         1012      Harry      Potter    7066950392
# 7         1013        Don      Draper  123-543-2345
# 8         1014     Leslie       Knope  876|678|3469
# 9         1015       Toby  Flenderson  304-762-2467
# 10        1016        Ron     Weasley  123-545-5421
# 11        1017    Michael       Scott  123/643/9775
# 12        1018      Clark        Kent    7066950392
# 13        1020     Anakin   Skywalker  876|678|3469
#
#                            Address Paying Customer Do_Not_Contact  \
# 0            123 Shire Lane, Shire             Yes              N
# ...

# %%
df.to_csv("world_population_clean.csv", index=False)
